# %%
import pandas as pd

plots = pd.read_csv("wiki_movie_plots_deduped.csv")

plots = plots[['Title', 'Origin/Ethnicity', 'Director','Genre','Release Year']]


#1
print("1.")
print(len(plots))

#2
print("\n2.")
print(plots.columns)

#3
print("\n3.")
print(len(plots.columns))

#4
print("\n4.")
print(plots.info())

#5
print("\n5.")
print(plots[len(plots)-8:len(plots)])

#6
print("\n6.")
print(plots.tail(8))

#7
print("\n7.")
print(plots[0:5])

#8
print("\n8.")
print(plots.head(5))

#9
print("\n9.")
print(plots["Genre"].value_counts().nlargest())

#10
print("\n10.")
print(plots["Director"].value_counts().nlargest())

#11
print("\n11.")
print(plots["Origin/Ethnicity"].value_counts())

#12
print("\n12.")
print(plots[plots.duplicated(["Title"],keep = False)])

#13
print("\n13.")
print(plots["Release Year"].value_counts())
# Out:
# 1.
# 34886
#
# 2.
# Index(['Title', 'Origin/Ethnicity', 'Director', 'Genre', 'Release Year'], dtype='object')
#
# 3.
# 5
#
# 4.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34886 entries, 0 to 34885
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             34886 non-null  object
#  1   Origin/Ethnicity  34886 non-null  object
#  2   Director          34886 non-null  object
#  3   Genre             34886 non-null  object
#  4   Release Year      34886 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 1.3+ MB
# None
#
# 5.
#                     Title Origin/Ethnicity                     Director  \
# 34878    Mandıra Filozofu          Turkish  Director: Müfit Can Saçıntı
# 34879        Winter Sleep          Turkish  Director: Nuri Bilge Ceylan
# 34880               Sivas          Turkish       Director: Kaan Müjdeci
# ...
